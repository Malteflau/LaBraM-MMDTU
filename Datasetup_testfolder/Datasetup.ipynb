# %%
import mne
import pandas as pd
import os
import pickle

folder_path = "/Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData"

fif_files = [f for f in os.listdir(folder_path) if f.endswith('.fif')]

epochs_list = []
t = 0
for file in fif_files:
    full_path = os.path.join(folder_path, file)
    epochs = mne.read_epochs(full_path, preload=True)
    epochs_list.append(epochs)
    t += 1
    if t == 10:
        break

print(f"\nTotal files loaded: {len(epochs_list)}")
# Out:
# Reading /Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData/326A_FG_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    5498.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 298 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData/311A_FG_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    5498.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData/318B_FG_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    5498.00 ms
#         0 CTF compensation matrices available
# ...

# %%
#read /Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData/326A_FG_preprocessed-epo.fif
import mne
epoch = mne.read_epochs("/Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData/315A_FG_preprocessed-epo.fif")
len(list(epoch))
epoch.get_data()
epoch.to_data_frame()
# Out:
# Reading /Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData/315A_FG_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    5498.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 295 matching events found
# No baseline correction applied
# 0 projection items activated
#          time condition  epoch       Fp1       AF7       AF3        F1  \
# 0      -0.500      T13P      0 -3.232223 -4.827953  0.109623  2.227646
# 1      -0.498      T13P      0 -2.877210 -4.990493  0.292530  2.499578
# 2      -0.496      T13P      0 -2.483588 -4.937266  0.458622  2.586790
# 3      -0.494      T13P      0 -2.018599 -4.639034  0.643795  2.517786
# 4      -0.492      T13P      0 -1.488466 -4.068369  0.859460  2.311579
# ...       ...       ...    ...       ...       ...       ...       ...
# 884995  5.490     T12Pn    299 -2.002948 -3.424034 -3.313947 -4.181121
# ...

# %%
#read /Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData/326A_FG_preprocessed-epo.fif
import mne
epoch = mne.read_epochs("/Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData/331A_FG_preprocessed-epo.fif")
len(list(epoch))
epoch.get_data()
df = epoch.to_data_frame()
# Out:
# Reading /Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData/331A_FG_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    5498.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 298 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
df[df["condition"] == "T12Pn"]
# Out:
#          time condition  epoch       Fp1        AF7       AF3        F1  \
# 15000  -0.500     T12Pn      5 -2.065771  -2.580251 -2.486794  0.795970
# 15001  -0.498     T12Pn      5 -2.492475  -2.334745 -2.764715  0.506119
# 15002  -0.496     T12Pn      5 -2.887758  -2.022593 -2.958102  0.270828
# 15003  -0.494     T12Pn      5 -3.164382  -1.658529 -3.047520  0.106650
# 15004  -0.492     T12Pn      5 -3.187586  -1.282497 -3.000530  0.065728
# ...       ...       ...    ...       ...        ...       ...       ...
# 863995  5.490     T12Pn    289 -5.864763 -10.021656 -7.810087 -3.352129
# 863996  5.492     T12Pn    289 -5.470848  -9.782546 -6.958853 -2.656144
# 863997  5.494     T12Pn    289 -5.244701  -9.638455 -6.229218 -2.134254
# 863998  5.496     T12Pn    289 -5.167734  -9.613406 -5.722241 -1.826118
# 863999  5.498     T12Pn    289 -5.257827  -9.801849 -5.509591 -1.752235
#
#               F3        F5         F7  ...       CP4       CP2        P2  \
# ...

# %%
FG_overview = pickle.load(open("/Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/FG_overview_df_v2.pkl", "rb"))
FG_overview
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 FG_overview = pickle.load(open("/Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/FG_overview_df_v2.pkl", "rb"))
#       2 FG_overview
#
# NameError: name 'pickle' is not defined

# %%
epochs_list[0]

# %%
Beh_features = pickle.load(open("/Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/Beh_feat_df_v2.pkl", "rb"))
print(Beh_features)
print(Beh_features.columns)
# Out:
#         Triad_id  Block  Trial  Condition_id Condition  Force_level  \
# 0            301      1      1             7      T13P            1
# 1            301      1      1             7      T13P            1
# 2            301      1      1             7      T13P            1
# 3            301      1      1             7      T13P            1
# 4            301      1      1             7      T13P            1
# ...          ...    ...    ...           ...       ...          ...
# 139495       331      6    300             8     T13Pn            1
# 139496       331      6    300             8     T13Pn            1
# 139497       331      6    300             8     T13Pn            1
# 139498       331      6    300             8     T13Pn            1
# 139499       331      6    300             8     T13Pn            1
#
#         TargetForce Participant        Feature     Value  Subject_id  \
# 0                16          P1        Latency  2.560000        1049
# ...

# %%
Force_df = pickle.load(open("/Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/Force_df_v2.pkl", "rb"))
Force_df
# Out:
#      Triad_id  Block  Trial  Condition_id Condition  Force_level  TargetForce  \
# 0         301      1     10            10     T23Pn            4           28
# 1         301      1     10            10     T23Pn            4           28
# 2         301      1     10            10     T23Pn            4           28
# 3         301      1     10            10     T23Pn            4           28
# 4         301      1     10            10     T23Pn            4           28
# ..        ...    ...    ...           ...       ...          ...          ...
# 500       331      6    300             8     T13Pn            1           16
# 501       331      6    300             8     T13Pn            1           16
# 502       331      6    300             8     T13Pn            1           16
# 503       331      6    300             8     T13Pn            1           16
# 504       331      6    300             8     T13Pn            1           16
#
# ...

# %%
epochs_list[0]
# Out:
# <EpochsFIF | 298 events (all good), -0.5 – 5.498 s (baseline off), ~436.6 MiB, data loaded,
#  'T1P': 30
#  'T1Pn': 29
#  'T3P': 30
#  'T3Pn': 30
#  'T12P': 30
#  'T12Pn': 29
#  'T13P': 30
#  'T13Pn': 30
#  'T23P': 30
#  'T23Pn': 30>

# %%
DataFrame = pd.DataFrame(epochs_list)

# %%
import mne
import pandas as pd
import numpy as np
import os
import pickle

# Define paths
folder_path = "/Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData"
force_data_path = "/Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/Force_df_v2.pkl"

# Load force data
with open(force_data_path, "rb") as f:
    force_df = pickle.load(f)

# Initialize lists to store data
all_data = []

# Get list of all .fif files
fif_files = [f for f in os.listdir(folder_path) if f.endswith('.fif')]
t=0
# Process each file
for fif_file in fif_files:
    t+=1
    if t==11:
        break
    # Extract participant ID from filename (assuming format like "301A_FG_preprocessed-epo.fif")
    participant_id = fif_file.split('_')[0]

    # Load epochs
    epochs = mne.read_epochs(os.path.join(folder_path, fif_file), preload=True)
    
    # Get data from epochs
    eeg_data = epochs.get_data()  # Shape: (n_epochs, n_channels, n_times)
    
    # For each epoch
    for epoch_idx in range(len(epochs)):
        # Get corresponding force data
        force_data = force_df[
            (force_df['Triad_id'] == int(participant_id[:3])) & 
            (force_df['Trial'] == epoch_idx + 1)
        ]
        
        if len(force_data) > 0:
            # Create row for each epoch
            row_data = {
                'participant_id': participant_id,
                'epoch_idx': epoch_idx,
                'condition': epochs.events[epoch_idx][2],  # Get condition from events
                'eeg_data': eeg_data[epoch_idx],  # Store full EEG data
                'force_level': force_data['Force_level'].iloc[0],
                'target_force': force_data['TargetForce'].iloc[0],
                'trial_time': force_data['Trial_time'].iloc[0],
                'force': force_data['Force'].iloc[0],
                'dforce': force_data['dForce'].iloc[0]
            }
            all_data.append(row_data)

# Create DataFrame
combined_df = pd.DataFrame(all_data)

# Example of filtering/accessing data
def get_condition_data(df, condition, participants=None):
    """
    Filter data by condition and optionally by participants
    """
    mask = df['condition'] == condition
    if participants:
        mask &= df['participant_id'].isin(participants)
    return df[mask]

# Example usage:
# Get all T23Pn trials
t23pn_data = get_condition_data(combined_df, 'T23Pn')

print(f"Combined DataFrame shape: {combined_df.shape}")
print("\nColumns:", combined_df.columns.tolist())
# Out:
# Reading /Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData/326A_FG_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    5498.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 298 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData/311A_FG_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    5498.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/maltelau/Desktop/LaBraM-MMDTU/LaBraM-MMDTU/DTUDATA/FG_Data/PreprocessedEEGData/318B_FG_preprocessed-epo.fif ...
#     Found the data of interest:
#         t =    -500.00 ...    5498.00 ms
#         0 CTF compensation matrices available
# ...

# %%
combined_df[combined_df['epoch_idx'] == 1]["eeg_data"]
values = list(combined_df[combined_df['epoch_idx'] == 1]["eeg_data"])
values[0].shape
# Out:
# (64, 3000)

# %%
# Out:
# '313C'

# %%
#find all epoch 1's in the data
epoch_1 = combined_df[combined_df['epoch_idx'] == 1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/labram/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /opt/anaconda3/envs/labram/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/envs/labram/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# ...
